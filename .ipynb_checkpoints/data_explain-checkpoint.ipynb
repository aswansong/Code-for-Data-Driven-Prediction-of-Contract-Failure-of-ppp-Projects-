# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.options.display.max_rows = 10
pd.options.display.max_columns = None

# %%
df1  = pd.read_excel('1900-1999.xlsx')
df2 = pd.read_excel('2000-2010.xlsx')
df3 = pd.read_excel('2010-2021.xlsx')
df_all = pd.concat([df1,df2,df3],axis=0,ignore_index=True)
select_df = df_all[['Region','ContractPeriod','Country','IncomeGroup',
        'IDA Status','Type of PPI','Project name','Project status',
        'Financial closure year','Capacity',
        'TotalInvestment','PhysicalAssets','Sponsors',
        'Sponsors Country','BiLateralSupport','Primary sector',
        'UnsolicitedProposal','PublicDisclosure','Subtype of PPI',
        'GovtGrantingContract','PercentPrivate','Subsector',
       'Segment','Main Revenue Source']]
select_df
# Out:
#                       Region ContractPeriod   Country          IncomeGroup  \
# 0      East Asia and Pacific             45  Cambodia           Low income
# 1      East Asia and Pacific             45  Cambodia           Low income
# 2      East Asia and Pacific             25  Cambodia           Low income
# 3      East Asia and Pacific             18  Cambodia           Low income
# 4      East Asia and Pacific             15  Cambodia           Low income
# ...                      ...            ...       ...                  ...
# 10149     Sub-Saharan Africa             25    Zambia  Lower middle income
# 10150     Sub-Saharan Africa  Not Available    Zambia  Lower middle income
# 10151     Sub-Saharan Africa             15  Zimbabwe           Low income
# 10152     Sub-Saharan Africa             25  Zimbabwe           Low income
# 10153     Sub-Saharan Africa             20  Zimbabwe           Low income
#
#       IDA Status         Type of PPI                      Project name  \
# 0            IDA          Brownfield  Pochentong International Airport
# 1            IDA          Brownfield  Pochentong International Airport
# 2            IDA  Greenfield project            Cambodia Power Company
# 3            IDA  Greenfield project    Cambodia Pte Ltd. Power Plant
# 4            IDA  Greenfield project          Jupiter Power Battambang
# ...          ...                 ...                               ...
# 10149        IDA  Greenfield project             Ngonye Solar PV Plant
# 10150        IDA  Greenfield project               Serenje solar plant
# 10151    Blended          Brownfield           Beitbridge Border Post
# 10152    Blended  Greenfield project          Kupinga small hydropower
# 10153    Blended  Greenfield project          Uhuru Energy Solar Plant
#
#       Project status  Financial closure year       Capacity TotalInvestment  \
# 0             Active                    1995  Not Available             120
# 1             Active                    1995  Not Available            23.2
# 2             Active                    1997             60              82
# 3             Active                    1997             35              45
# 4             Active                    1999             15              10
# ...              ...                     ...            ...             ...
# 10149         Active                    2018             34              45
# 10150         Active                    2021            200             336
# 10151         Active                    2011  Not Available              97
# 10152         Active                    2017            1.6             5.7
# 10153         Active                    2017             60              60
#
#       PhysicalAssets                                           Sponsors  \
# 0                120  Muhibbah Engineering (Not Available / 30% ), \...
# 1               23.2  Muhibbah Engineering (Not Available / 30% ), \...
# 2                 82  Beacon Hill (Not Available / Not Available% ),...
# 3                 45  Leader Universal Holdings (Not Available / 60%...
# 4                 10  Maxim Power Corporation (Not Available / 51% )...
# ...              ...                                                ...
# 10149             45    Enel SpA ($9 / 80% ), \n\rOthers ($2.25 / 20% )
# 10150            336             Ultra Green Corporation ($336 / 100% )
# 10151             97  Old Mutual (Not Available / Not Available% ), ...
# 10152            5.7                          Old Mutual ($5.7 / 100% )
# 10153             60        Others ($51 / 85% ), \n\rOthers ($9 / 15% )
#
#                                        Sponsors Country BiLateralSupport  \
# 0                                  Cambodia, \n\rFrance               No
# 1                                  Cambodia, \n\rFrance               No
# 2                                            .., \n\r..               No
# 3                                    .., \n\r.., \n\r..               No
# 4                             Canada, \n\rUnited States               No
# ...                                                 ...              ...
# 10149                                     Italy, \n\r..               No
# 10150                                     United States              NaN
# 10151  South Africa, \n\rSouth Africa, \n\rSouth Africa               No
# 10152                                      South Africa               No
# 10153                                        .., \n\r..               No
#
#       Primary sector UnsolicitedProposal PublicDisclosure  \
# 0          Transport                 Yes               No
# 1          Transport                 Yes               No
# 2             Energy                 Yes               No
# 3             Energy                 Yes               No
# 4             Energy                 Yes               No
# ...              ...                 ...              ...
# 10149         Energy                 Yes               No
# 10150         Energy                  No               No
# 10151      Transport                 Yes               No
# 10152         Energy                 Yes               No
# 10153         Energy                 Yes               No
#
#                                    Subtype of PPI GovtGrantingContract  \
# 0      Build, rehabilitate, operate, and transfer        Not Available
# 1      Build, rehabilitate, operate, and transfer        Not Available
# 2                         Build, own, and operate        Not Available
# 3                    Build, operate, and transfer        Not Available
# 4                    Build, operate, and transfer        Not Available
# ...                                           ...                  ...
# 10149                     Build, own, and operate             National
# 10150                     Build, own, and operate             National
# 10151  Build, rehabilitate, operate, and transfer             National
# 10152                     Build, own, and operate             National
# 10153                     Build, own, and operate             National
#
#       PercentPrivate    Subsector                 Segment  \
# 0                100     Airports     Runway and terminal
# 1                100     Airports     Runway and terminal
# 2                100  Electricity  Electricity generation
# 3                100  Electricity  Electricity generation
# 4                100  Electricity  Electricity generation
# ...              ...          ...                     ...
# 10149             80  Electricity  Electricity generation
# 10150            100  Electricity  Electricity generation
# 10151            100        Roads                 Highway
# 10152            100  Electricity  Electricity generation
# 10153            100  Electricity  Electricity generation
#
#                                      Main Revenue Source
# 0                                         Not Applicable
# 1                                         Not Applicable
# 2                                         Not Applicable
# 3                                         Not Applicable
# 4                                         Not Applicable
# ...                                                  ...
# 10149  Purchase agreements or transmission fees with ...
# 10150  Purchase agreements or transmission fees with ...
# 10151                                          User fees
# 10152  Purchase agreements or transmission fees with ...
# 10153  Purchase agreements or transmission fees with ...
#
# [10154 rows x 24 columns]

# %%
def trainsform_float(se):
    for i in range(len(se)):
        if  se[i] == 'Not Available' or se[i] =='Not Applicable':
            se[i]=0.00001
    se = se.astype(float)
    se_mean = round(se.mean())
    print(se_mean)
    for i in range(len(se)):
        if se[i]==0.00001:
            se[i]=se_mean
    return se
    
select_df['ContractPeriod'] = trainsform_float(select_df['ContractPeriod'])
select_df['Capacity'] = trainsform_float(select_df['Capacity'])
select_df['PercentPrivate'] = trainsform_float(select_df['PercentPrivate'])
select_df['PhysicalAssets'] = trainsform_float(select_df['PhysicalAssets'])
select_df['TotalInvestment'] = trainsform_float(select_df['TotalInvestment'])
select_df
# Out:
# 18
# 6006
# 87
# 170
# 200
#                       Region  ContractPeriod   Country          IncomeGroup  \
# 0      East Asia and Pacific            45.0  Cambodia           Low income
# 1      East Asia and Pacific            45.0  Cambodia           Low income
# 2      East Asia and Pacific            25.0  Cambodia           Low income
# 3      East Asia and Pacific            18.0  Cambodia           Low income
# 4      East Asia and Pacific            15.0  Cambodia           Low income
# ...                      ...             ...       ...                  ...
# 10149     Sub-Saharan Africa            25.0    Zambia  Lower middle income
# 10150     Sub-Saharan Africa            18.0    Zambia  Lower middle income
# 10151     Sub-Saharan Africa            15.0  Zimbabwe           Low income
# 10152     Sub-Saharan Africa            25.0  Zimbabwe           Low income
# 10153     Sub-Saharan Africa            20.0  Zimbabwe           Low income
#
#       IDA Status         Type of PPI                      Project name  \
# 0            IDA          Brownfield  Pochentong International Airport
# 1            IDA          Brownfield  Pochentong International Airport
# 2            IDA  Greenfield project            Cambodia Power Company
# 3            IDA  Greenfield project    Cambodia Pte Ltd. Power Plant
# 4            IDA  Greenfield project          Jupiter Power Battambang
# ...          ...                 ...                               ...
# 10149        IDA  Greenfield project             Ngonye Solar PV Plant
# 10150        IDA  Greenfield project               Serenje solar plant
# 10151    Blended          Brownfield           Beitbridge Border Post
# 10152    Blended  Greenfield project          Kupinga small hydropower
# 10153    Blended  Greenfield project          Uhuru Energy Solar Plant
#
#       Project status  Financial closure year  Capacity  TotalInvestment  \
# 0             Active                    1995    6006.0            120.0
# 1             Active                    1995    6006.0             23.2
# 2             Active                    1997      60.0             82.0
# 3             Active                    1997      35.0             45.0
# 4             Active                    1999      15.0             10.0
# ...              ...                     ...       ...              ...
# 10149         Active                    2018      34.0             45.0
# 10150         Active                    2021     200.0            336.0
# 10151         Active                    2011    6006.0             97.0
# 10152         Active                    2017       1.6              5.7
# 10153         Active                    2017      60.0             60.0
#
#        PhysicalAssets                                           Sponsors  \
# 0               120.0  Muhibbah Engineering (Not Available / 30% ), \...
# 1                23.2  Muhibbah Engineering (Not Available / 30% ), \...
# 2                82.0  Beacon Hill (Not Available / Not Available% ),...
# 3                45.0  Leader Universal Holdings (Not Available / 60%...
# 4                10.0  Maxim Power Corporation (Not Available / 51% )...
# ...               ...                                                ...
# 10149            45.0    Enel SpA ($9 / 80% ), \n\rOthers ($2.25 / 20% )
# 10150           336.0             Ultra Green Corporation ($336 / 100% )
# 10151            97.0  Old Mutual (Not Available / Not Available% ), ...
# 10152             5.7                          Old Mutual ($5.7 / 100% )
# 10153            60.0        Others ($51 / 85% ), \n\rOthers ($9 / 15% )
#
#                                        Sponsors Country BiLateralSupport  \
# 0                                  Cambodia, \n\rFrance               No
# 1                                  Cambodia, \n\rFrance               No
# 2                                            .., \n\r..               No
# 3                                    .., \n\r.., \n\r..               No
# 4                             Canada, \n\rUnited States               No
# ...                                                 ...              ...
# 10149                                     Italy, \n\r..               No
# 10150                                     United States              NaN
# 10151  South Africa, \n\rSouth Africa, \n\rSouth Africa               No
# 10152                                      South Africa               No
# 10153                                        .., \n\r..               No
#
#       Primary sector UnsolicitedProposal PublicDisclosure  \
# 0          Transport                 Yes               No
# 1          Transport                 Yes               No
# 2             Energy                 Yes               No
# 3             Energy                 Yes               No
# 4             Energy                 Yes               No
# ...              ...                 ...              ...
# 10149         Energy                 Yes               No
# 10150         Energy                  No               No
# 10151      Transport                 Yes               No
# 10152         Energy                 Yes               No
# 10153         Energy                 Yes               No
#
#                                    Subtype of PPI GovtGrantingContract  \
# 0      Build, rehabilitate, operate, and transfer        Not Available
# 1      Build, rehabilitate, operate, and transfer        Not Available
# 2                         Build, own, and operate        Not Available
# 3                    Build, operate, and transfer        Not Available
# 4                    Build, operate, and transfer        Not Available
# ...                                           ...                  ...
# 10149                     Build, own, and operate             National
# 10150                     Build, own, and operate             National
# 10151  Build, rehabilitate, operate, and transfer             National
# 10152                     Build, own, and operate             National
# 10153                     Build, own, and operate             National
#
#        PercentPrivate    Subsector                 Segment  \
# 0               100.0     Airports     Runway and terminal
# 1               100.0     Airports     Runway and terminal
# 2               100.0  Electricity  Electricity generation
# 3               100.0  Electricity  Electricity generation
# 4               100.0  Electricity  Electricity generation
# ...               ...          ...                     ...
# 10149            80.0  Electricity  Electricity generation
# 10150           100.0  Electricity  Electricity generation
# 10151           100.0        Roads                 Highway
# 10152           100.0  Electricity  Electricity generation
# 10153           100.0  Electricity  Electricity generation
#
#                                      Main Revenue Source
# 0                                         Not Applicable
# 1                                         Not Applicable
# 2                                         Not Applicable
# 3                                         Not Applicable
# 4                                         Not Applicable
# ...                                                  ...
# 10149  Purchase agreements or transmission fees with ...
# 10150  Purchase agreements or transmission fees with ...
# 10151                                          User fees
# 10152  Purchase agreements or transmission fees with ...
# 10153  Purchase agreements or transmission fees with ...
#
# [10154 rows x 24 columns]

# %%
def wgi_data_add(sheetname):
    wgi_data = pd.read_excel('wgidataset.xlsx',header=[13,14],sheet_name=sheetname)
    for index,row in wgi_data.iteritems():
        # print(index)
        if row.dtype=="float64":
            mean_value = row.mean()
            row.fillna(mean_value,inplace=True)
    country_wgi = wgi_data[('Unnamed: 0_level_0', 'Country/Territory')]
    add_list = []
    for i in range(len(select_df['Country'])):
    #     index_number = country_wgi[country_wgi.values == select_df['Country'][i]].index
    #     if select_df['Financial closure year'][i]%2==0:
    #         a = select_df['Financial closure year'][i]
    #         add_list.append(wgi_data.loc[index_number[0],(a, 'Estimate')])
    #     elif select_df['Financial closure year'][i]%2==1:
    #         a = select_df['Financial closure year'][i]-1
    #         # print(a,index_number[0])
    #         add_list.append(wgi_data.loc[index_number[0],(a, 'Estimate')])
        try:
            index_number = country_wgi[country_wgi.values == select_df['Country'][i]].index
            if select_df['Financial closure year'][i]%2==0:
                a = select_df['Financial closure year'][i]
                add_list.append(wgi_data.loc[index_number[0],(a, 'Estimate')])
            elif select_df['Financial closure year'][i]%2==1:
                a = select_df['Financial closure year'][i]-1
                add_list.append(wgi_data.loc[index_number[0],(a, 'Estimate')])
        except:
            add_list.append(0)
    select_df.insert(select_df.shape[1], sheetname, add_list)
wgi_data_add('VoiceandAccountability')
wgi_data_add('Political StabilityNoViolence')
wgi_data_add('GovernmentEffectiveness')
wgi_data_add('RegulatoryQuality')
wgi_data_add('RuleofLaw')
wgi_data_add('ControlofCorruption')
select_df
# Out:
#                       Region  ContractPeriod   Country          IncomeGroup  \
# 0      East Asia and Pacific            45.0  Cambodia           Low income
# 1      East Asia and Pacific            45.0  Cambodia           Low income
# 2      East Asia and Pacific            25.0  Cambodia           Low income
# 3      East Asia and Pacific            18.0  Cambodia           Low income
# 4      East Asia and Pacific            15.0  Cambodia           Low income
# ...                      ...             ...       ...                  ...
# 10149     Sub-Saharan Africa            25.0    Zambia  Lower middle income
# 10150     Sub-Saharan Africa            18.0    Zambia  Lower middle income
# 10151     Sub-Saharan Africa            15.0  Zimbabwe           Low income
# 10152     Sub-Saharan Africa            25.0  Zimbabwe           Low income
# 10153     Sub-Saharan Africa            20.0  Zimbabwe           Low income
#
#       IDA Status         Type of PPI                      Project name  \
# 0            IDA          Brownfield  Pochentong International Airport
# 1            IDA          Brownfield  Pochentong International Airport
# 2            IDA  Greenfield project            Cambodia Power Company
# 3            IDA  Greenfield project    Cambodia Pte Ltd. Power Plant
# 4            IDA  Greenfield project          Jupiter Power Battambang
# ...          ...                 ...                               ...
# 10149        IDA  Greenfield project             Ngonye Solar PV Plant
# 10150        IDA  Greenfield project               Serenje solar plant
# 10151    Blended          Brownfield           Beitbridge Border Post
# 10152    Blended  Greenfield project          Kupinga small hydropower
# 10153    Blended  Greenfield project          Uhuru Energy Solar Plant
#
#       Project status  Financial closure year  Capacity  TotalInvestment  \
# 0             Active                    1995    6006.0            120.0
# 1             Active                    1995    6006.0             23.2
# 2             Active                    1997      60.0             82.0
# 3             Active                    1997      35.0             45.0
# 4             Active                    1999      15.0             10.0
# ...              ...                     ...       ...              ...
# 10149         Active                    2018      34.0             45.0
# 10150         Active                    2021     200.0            336.0
# 10151         Active                    2011    6006.0             97.0
# 10152         Active                    2017       1.6              5.7
# 10153         Active                    2017      60.0             60.0
#
#        PhysicalAssets                                           Sponsors  \
# 0               120.0  Muhibbah Engineering (Not Available / 30% ), \...
# 1                23.2  Muhibbah Engineering (Not Available / 30% ), \...
# 2                82.0  Beacon Hill (Not Available / Not Available% ),...
# 3                45.0  Leader Universal Holdings (Not Available / 60%...
# 4                10.0  Maxim Power Corporation (Not Available / 51% )...
# ...               ...                                                ...
# 10149            45.0    Enel SpA ($9 / 80% ), \n\rOthers ($2.25 / 20% )
# 10150           336.0             Ultra Green Corporation ($336 / 100% )
# 10151            97.0  Old Mutual (Not Available / Not Available% ), ...
# 10152             5.7                          Old Mutual ($5.7 / 100% )
# 10153            60.0        Others ($51 / 85% ), \n\rOthers ($9 / 15% )
#
#                                        Sponsors Country BiLateralSupport  \
# 0                                  Cambodia, \n\rFrance               No
# 1                                  Cambodia, \n\rFrance               No
# 2                                            .., \n\r..               No
# 3                                    .., \n\r.., \n\r..               No
# 4                             Canada, \n\rUnited States               No
# ...                                                 ...              ...
# 10149                                     Italy, \n\r..               No
# 10150                                     United States              NaN
# 10151  South Africa, \n\rSouth Africa, \n\rSouth Africa               No
# 10152                                      South Africa               No
# 10153                                        .., \n\r..               No
#
#       Primary sector UnsolicitedProposal PublicDisclosure  \
# 0          Transport                 Yes               No
# 1          Transport                 Yes               No
# 2             Energy                 Yes               No
# 3             Energy                 Yes               No
# 4             Energy                 Yes               No
# ...              ...                 ...              ...
# 10149         Energy                 Yes               No
# 10150         Energy                  No               No
# 10151      Transport                 Yes               No
# 10152         Energy                 Yes               No
# 10153         Energy                 Yes               No
#
#                                    Subtype of PPI GovtGrantingContract  \
# 0      Build, rehabilitate, operate, and transfer        Not Available
# 1      Build, rehabilitate, operate, and transfer        Not Available
# 2                         Build, own, and operate        Not Available
# 3                    Build, operate, and transfer        Not Available
# 4                    Build, operate, and transfer        Not Available
# ...                                           ...                  ...
# 10149                     Build, own, and operate             National
# 10150                     Build, own, and operate             National
# 10151  Build, rehabilitate, operate, and transfer             National
# 10152                     Build, own, and operate             National
# 10153                     Build, own, and operate             National
#
#        PercentPrivate    Subsector                 Segment  \
# 0               100.0     Airports     Runway and terminal
# 1               100.0     Airports     Runway and terminal
# 2               100.0  Electricity  Electricity generation
# 3               100.0  Electricity  Electricity generation
# 4               100.0  Electricity  Electricity generation
# ...               ...          ...                     ...
# 10149            80.0  Electricity  Electricity generation
# 10150           100.0  Electricity  Electricity generation
# 10151           100.0        Roads                 Highway
# 10152           100.0  Electricity  Electricity generation
# 10153           100.0  Electricity  Electricity generation
#
#                                      Main Revenue Source  \
# 0                                         Not Applicable
# 1                                         Not Applicable
# 2                                         Not Applicable
# 3                                         Not Applicable
# 4                                         Not Applicable
# ...                                                  ...
# 10149  Purchase agreements or transmission fees with ...
# 10150  Purchase agreements or transmission fees with ...
# 10151                                          User fees
# 10152  Purchase agreements or transmission fees with ...
# 10153  Purchase agreements or transmission fees with ...
#
#        VoiceandAccountability  Political StabilityNoViolence  \
# 0                    0.000000                       0.000000
# 1                    0.000000                       0.000000
# 2                   -0.749472                      -1.104553
# 3                   -0.749472                      -1.104553
# 4                   -0.815466                      -1.264929
# ...                       ...                            ...
# 10149               -0.342629                       0.085604
# 10150               -0.428637                      -0.130104
# 10151               -1.475182                      -1.104014
# 10152               -1.178460                      -0.619938
# 10153               -1.178460                      -0.619938
#
#        GovernmentEffectiveness  RegulatoryQuality  RuleofLaw  \
# 0                     0.000000           0.000000   0.000000
# 1                     0.000000           0.000000   0.000000
# 2                    -0.724763          -0.227968  -1.194369
# 3                    -0.724763          -0.227968  -1.194369
# 4                    -0.874252          -0.163952  -1.178635
# ...                        ...                ...        ...
# 10149                -0.624778          -0.510764  -0.339549
# 10150                -0.802456          -0.670564  -0.632692
# 10151                -1.538160          -2.001824  -1.837632
# 10152                -1.209890          -1.684896  -1.381370
# 10153                -1.209890          -1.684896  -1.381370
#
#        ControlofCorruption
# 0                 0.000000
# 1                 0.000000
# 2                -1.019842
# 3                -1.019842
# 4                -0.988312
# ...                    ...
# 10149            -0.657134
# 10150            -0.723668
# 10151            -1.373287
# 10152            -1.271258
# 10153            -1.271258
#
# [10154 rows x 30 columns]

# %%
wdi_data = pd.read_csv('WDI/data.csv')
data_by = wdi_data.groupby('Series Name')
for index_progect,df_wdi in data_by:
    new_df = df_wdi.copy(deep=True)
    new_df.reset_index(drop=True, inplace=True)
    for name,row in new_df.iteritems():
        if 'YR' in name:
            for i in range(len(row)):
                if row[i]=='..':
                    row[i] =0.000001
            row = row.astype(float)
            mean_wid  = round(row.mean())
            for i in range(len(row)):
                if row[i]==0.000001:
                    row[i]=mean_wid
                    
    add_list =[]
    country_name  = new_df['Country Name']
    for i in range(len(select_df['Country'])):
        # index_number = country_name[country_name.values == select_df['Country'][i]].index
        # a = select_df['Financial closure year'][i]
        # if len(index_number)!=0:
        #     add_list.append(new_df.loc[index_number[0],f'{a} [YR{a}]'])
        try:
            index_number = country_name[country_name.values == select_df['Country'][i]].index
            a = select_df['Financial closure year'][i]
            if len(index_number)!=0:
                add_list.append(new_df.loc[index_number[0],f'{a} [YR{a}]'])
            else:
                mean_value = new_df[f'{a} [YR{a}]'].mean()
                # print(mean_value)
                add_list.append(mean_value)
        except:
            add_list.append(0)
    # print(add_list)
    try:
        select_df.insert(select_df.shape[1], index_progect, add_list)
    except:
        pass
    select_df[index_progect]=select_df[index_progect].astype('float')
select_df
# Out:
#                       Region  ContractPeriod   Country          IncomeGroup  \
# 0      East Asia and Pacific            45.0  Cambodia           Low income
# 1      East Asia and Pacific            45.0  Cambodia           Low income
# 2      East Asia and Pacific            25.0  Cambodia           Low income
# 3      East Asia and Pacific            18.0  Cambodia           Low income
# 4      East Asia and Pacific            15.0  Cambodia           Low income
# ...                      ...             ...       ...                  ...
# 10149     Sub-Saharan Africa            25.0    Zambia  Lower middle income
# 10150     Sub-Saharan Africa            18.0    Zambia  Lower middle income
# 10151     Sub-Saharan Africa            15.0  Zimbabwe           Low income
# 10152     Sub-Saharan Africa            25.0  Zimbabwe           Low income
# 10153     Sub-Saharan Africa            20.0  Zimbabwe           Low income
#
#       IDA Status         Type of PPI                      Project name  \
# 0            IDA          Brownfield  Pochentong International Airport
# 1            IDA          Brownfield  Pochentong International Airport
# 2            IDA  Greenfield project            Cambodia Power Company
# 3            IDA  Greenfield project    Cambodia Pte Ltd. Power Plant
# 4            IDA  Greenfield project          Jupiter Power Battambang
# ...          ...                 ...                               ...
# 10149        IDA  Greenfield project             Ngonye Solar PV Plant
# 10150        IDA  Greenfield project               Serenje solar plant
# 10151    Blended          Brownfield           Beitbridge Border Post
# 10152    Blended  Greenfield project          Kupinga small hydropower
# 10153    Blended  Greenfield project          Uhuru Energy Solar Plant
#
#       Project status  Financial closure year  Capacity  TotalInvestment  \
# 0             Active                    1995    6006.0            120.0
# 1             Active                    1995    6006.0             23.2
# 2             Active                    1997      60.0             82.0
# 3             Active                    1997      35.0             45.0
# 4             Active                    1999      15.0             10.0
# ...              ...                     ...       ...              ...
# 10149         Active                    2018      34.0             45.0
# 10150         Active                    2021     200.0            336.0
# 10151         Active                    2011    6006.0             97.0
# 10152         Active                    2017       1.6              5.7
# 10153         Active                    2017      60.0             60.0
#
#        PhysicalAssets                                           Sponsors  \
# 0               120.0  Muhibbah Engineering (Not Available / 30% ), \...
# 1                23.2  Muhibbah Engineering (Not Available / 30% ), \...
# 2                82.0  Beacon Hill (Not Available / Not Available% ),...
# 3                45.0  Leader Universal Holdings (Not Available / 60%...
# 4                10.0  Maxim Power Corporation (Not Available / 51% )...
# ...               ...                                                ...
# 10149            45.0    Enel SpA ($9 / 80% ), \n\rOthers ($2.25 / 20% )
# 10150           336.0             Ultra Green Corporation ($336 / 100% )
# 10151            97.0  Old Mutual (Not Available / Not Available% ), ...
# 10152             5.7                          Old Mutual ($5.7 / 100% )
# 10153            60.0        Others ($51 / 85% ), \n\rOthers ($9 / 15% )
#
#                                        Sponsors Country BiLateralSupport  \
# 0                                  Cambodia, \n\rFrance               No
# 1                                  Cambodia, \n\rFrance               No
# 2                                            .., \n\r..               No
# 3                                    .., \n\r.., \n\r..               No
# 4                             Canada, \n\rUnited States               No
# ...                                                 ...              ...
# 10149                                     Italy, \n\r..               No
# 10150                                     United States              NaN
# 10151  South Africa, \n\rSouth Africa, \n\rSouth Africa               No
# 10152                                      South Africa               No
# 10153                                        .., \n\r..               No
#
#       Primary sector UnsolicitedProposal PublicDisclosure  \
# 0          Transport                 Yes               No
# 1          Transport                 Yes               No
# 2             Energy                 Yes               No
# 3             Energy                 Yes               No
# 4             Energy                 Yes               No
# ...              ...                 ...              ...
# 10149         Energy                 Yes               No
# 10150         Energy                  No               No
# 10151      Transport                 Yes               No
# 10152         Energy                 Yes               No
# 10153         Energy                 Yes               No
#
#                                    Subtype of PPI GovtGrantingContract  \
# 0      Build, rehabilitate, operate, and transfer        Not Available
# 1      Build, rehabilitate, operate, and transfer        Not Available
# 2                         Build, own, and operate        Not Available
# 3                    Build, operate, and transfer        Not Available
# 4                    Build, operate, and transfer        Not Available
# ...                                           ...                  ...
# 10149                     Build, own, and operate             National
# 10150                     Build, own, and operate             National
# 10151  Build, rehabilitate, operate, and transfer             National
# 10152                     Build, own, and operate             National
# 10153                     Build, own, and operate             National
#
#        PercentPrivate    Subsector                 Segment  \
# 0               100.0     Airports     Runway and terminal
# 1               100.0     Airports     Runway and terminal
# 2               100.0  Electricity  Electricity generation
# 3               100.0  Electricity  Electricity generation
# 4               100.0  Electricity  Electricity generation
# ...               ...          ...                     ...
# 10149            80.0  Electricity  Electricity generation
# 10150           100.0  Electricity  Electricity generation
# 10151           100.0        Roads                 Highway
# 10152           100.0  Electricity  Electricity generation
# 10153           100.0  Electricity  Electricity generation
#
#                                      Main Revenue Source  \
# 0                                         Not Applicable
# 1                                         Not Applicable
# 2                                         Not Applicable
# 3                                         Not Applicable
# 4                                         Not Applicable
# ...                                                  ...
# 10149  Purchase agreements or transmission fees with ...
# 10150  Purchase agreements or transmission fees with ...
# 10151                                          User fees
# 10152  Purchase agreements or transmission fees with ...
# 10153  Purchase agreements or transmission fees with ...
#
#        VoiceandAccountability  Political StabilityNoViolence  \
# 0                    0.000000                       0.000000
# 1                    0.000000                       0.000000
# 2                   -0.749472                      -1.104553
# 3                   -0.749472                      -1.104553
# 4                   -0.815466                      -1.264929
# ...                       ...                            ...
# 10149               -0.342629                       0.085604
# 10150               -0.428637                      -0.130104
# 10151               -1.475182                      -1.104014
# 10152               -1.178460                      -0.619938
# 10153               -1.178460                      -0.619938
#
#        GovernmentEffectiveness  RegulatoryQuality  RuleofLaw  \
# 0                     0.000000           0.000000   0.000000
# 1                     0.000000           0.000000   0.000000
# 2                    -0.724763          -0.227968  -1.194369
# 3                    -0.724763          -0.227968  -1.194369
# 4                    -0.874252          -0.163952  -1.178635
# ...                        ...                ...        ...
# 10149                -0.624778          -0.510764  -0.339549
# 10150                -0.802456          -0.670564  -0.632692
# 10151                -1.538160          -2.001824  -1.837632
# 10152                -1.209890          -1.684896  -1.381370
# 10153                -1.209890          -1.684896  -1.381370
#
#        ControlofCorruption  Access to electricity (% of population)  \
# 0                 0.000000                                 0.000001
# 1                 0.000000                                 0.000001
# 2                -1.019842                                 0.000001
# 3                -1.019842                                 0.000001
# 4                -0.988312                                 8.820037
# ...                    ...                                      ...
# 10149            -0.657134                                40.317890
# 10150            -0.723668                                 0.000001
# 10151            -1.373287                                36.900002
# 10152            -1.271258                                44.178635
# 10153            -1.271258                                44.178635
#
#        Domestic credit to private sector (% of GDP)  \
# 0                                          3.478933
# 1                                          3.478933
# 2                                          6.276632
# 3                                          6.276632
# 4                                          5.705935
# ...                                             ...
# 10149                                     14.973719
# 10150                                      0.000001
# 10151                                     18.983236
# 10152                                     16.875108
# 10153                                     16.875108
#
#        Exports of goods and services (% of GDP)  \
# 0                                     31.184182
# 1                                     31.184182
# 2                                     33.616936
# 3                                     33.616936
# 4                                     40.544186
# ...                                         ...
# 10149                                 37.957405
# 10150                                 52.078387
# 10151                                 34.800802
# 10152                                 19.658905
# 10153                                 19.658905
#
#        GDP deflator (base year varies by country)  \
# 0                                       85.598011
# 1                                       85.598011
# 2                                       93.489876
# 3                                       93.489876
# 4                                      104.474897
# ...                                           ...
# 10149                                  196.992010
# 10150                                  307.698237
# 10151                                    8.490567
# 10152                                   10.217760
# 10153                                   10.217760
#
#        GDP per capita (constant 2015 US$)  \
# 0                              378.922378
# 1                              378.922378
# 2                              398.652963
# 3                              398.652963
# 4                              451.861451
# ...                                   ...
# 10149                         1331.449244
# 10150                         1257.934757
# 10151                         1239.241794
# 10152                         1421.240770
# 10153                         1421.240770
#
#        Imports of goods and services (% of GDP)  \
# 0                                     46.582547
# 1                                     46.582547
# 2                                     45.317709
# 3                                     45.317709
# 4                                     53.632702
# ...                                         ...
# 10149                                 36.930965
# 10150                                 33.913790
# 10151                                 54.665725
# 10152                                 30.370807
# 10153                                 30.370807
#
#        Life expectancy at birth, total (years)  \
# 0                                    56.308000
# 1                                    56.308000
# 2                                    56.743000
# 3                                    56.743000
# 4                                    57.690000
# ...                                        ...
# 10149                                62.342000
# 10150                                 0.000001
# 10151                                53.347000
# 10152                                60.709000
# 10153                                60.709000
#
#        Official exchange rate (LCU per US$, period average)  \
# 0                                            2450.833333
# 1                                            2450.833333
# 2                                            2946.250000
# 3                                            2946.250000
# 4                                            3807.833333
# ...                                                  ...
# 10149                                          10.458333
# 10150                                          20.018487
# 10151                                           0.000001
# 10152                                           0.000001
# 10153                                           0.000001
#
#        Tax revenue (% of GDP)
# 0                    0.000001
# 1                    0.000001
# 2                    0.000001
# 3                    0.000001
# 4                    0.000001
# ...                       ...
# 10149               16.587065
# 10150                0.000001
# 10151               17.928254
# 10152               15.874375
# 10153               15.874375
#
# [10154 rows x 39 columns]

# %%
for index,row in select_df.iteritems():
    print('\n'+'数据库：',index)
    try:
        print('mean:',row.mean())
        print('max:',row.max())
        print('min:',row.min())
    except:
        print('分类文本数据，无值')
        print(row.value_counts())
# Out:
# 数据库： Region
# 分类文本数据，无值
# Latin America and the Caribbean    3865
# East Asia and Pacific              2814
# South Asia                         1627
# Europe and Central Asia            1070
# Sub-Saharan Africa                  575
# Middle East and North Africa        203
# Name: Region, dtype: int64
#
# 数据库： ContractPeriod
# mean: 23.655406736261572
# max: 99.0
# min: 1.0
#
# 数据库： Country
# 分类文本数据，无值
# Brazil                            1943
# China                             1806
# India                             1270
# Argentina                          599
# Mexico                             395
#                                   ...
# St. Vincent and the Grenadines       1
# St. Kitts and Nevis                  1
# Mauritania                           1
# Eswatini                             1
# Lesotho                              1
# Name: Country, Length: 125, dtype: int64
#
# 数据库： IncomeGroup
# 分类文本数据，无值
# Upper middle income    6942
# Lower middle income    2933
# Low income              279
# Name: IncomeGroup, dtype: int64
#
# 数据库： IDA Status
# 分类文本数据，无值
# Non-IDA    8916
# IDA         619
# Blended     619
# Name: IDA Status, dtype: int64
#
# 数据库： Type of PPI
# 分类文本数据，无值
# Greenfield project               5573
# Brownfield                       3056
# Divestiture                      1132
# Management and lease contract     393
# Name: Type of PPI, dtype: int64
#
# 数据库： Project name
# 分类文本数据，无值
# Espirito Santo Centrais Eletricas SA (ESCELSA)        21
# Light Servicos de Eletricidade SA                     20
# Edesur SA                                             20
# MRS Logistica SA                                      20
# Ferrovia Novoeste S.A.                                20
#                                                       ..
# KCC Lateri Expressway Private Limited                  1
# Malindi water utility contract                         1
# Santa Rosa II Hydroelectric Plant                      1
# Binjiang Plant and Chengxi Plant Upgrading Project     1
# Zarqa CCGT power plant                                 1
# Name: Project name, Length: 7612, dtype: int64
#
# 数据库： Project status
# 分类文本数据，无值
# Active        9368
# Cancelled      308
# Distressed     257
# Concluded      221
# Name: Project status, dtype: int64
#
# 数据库： Financial closure year
# mean: 2006.118376994288
# max: 2021
# min: 1990
#
# 数据库： Capacity
# mean: 7003.555813354343
# max: 50000000.0
# min: 0.03
#
# 数据库： TotalInvestment
# mean: 224.3574970336813
# max: 35586.5
# min: 0.03
#
# 数据库： PhysicalAssets
# mean: 181.31069506893834
# max: 14800.0
# min: 0.0
#
# 数据库： Sponsors
# 分类文本数据，无值
# Others (Not Available / Not Available% )                                                                                                                                                                                                                279
# Others (Not Available / 100% )                                                                                                                                                                                                                          138
# Grupo Energisa (Not Available / 100% )                                                                                                                                                                                                                   91
# CPFL Energia (Not Available / 100% )                                                                                                                                                                                                                     80
# Beijing Sound Environment Industry Group (Not Available / 100% )                                                                                                                                                                                         58
#                                                                                                                                                                                                                                                        ...
# GVK Group (Not Available / Not Available% ), \n\rMaytas Infrastructure Pvt Ltd (Not Available / Not Available% ), \n\rIJM Corporation Berhad (Not Available / Not Available% ), \n\rNagarjuna Construction Company (Not Available / Not Available% )      1
# Orion Group ($26 / 100% )                                                                                                                                                                                                                                 1
# RAG Beteiligungs-Group (Not Available / 51% ), \n\rOrdu Yardimlasma Kurumu (Not Available / 49% )                                                                                                                                                         1
# Alupar (Not Available / 100% )                                                                                                                                                                                                                            1
# Genting Group (Not Available / 95% )                                                                                                                                                                                                                      1
# Name: Sponsors, Length: 5435, dtype: int64
#
# 数据库： Sponsors Country
# 分类文本数据，无值
# ..                                           957
# India                                        858
# China                                        853
# Brazil                                       718
# United States                                391
#                                             ...
# Colombia, \n\rColombia, \n\rFrance             1
# Denmark, \n\rNetherlands                       1
# Switzerland, \n\rBurkina Faso                  1
# Saudi Arabia, \n\rItaly                        1
# Mexico, \n\rMexico, \n\rSpain, \n\rMexico      1
# Name: Sponsors Country, Length: 1119, dtype: int64
#
# 数据库： BiLateralSupport
# 分类文本数据，无值
# No                                                                                  9267
#  Proparco (Loan / $66 Million / 2013), \n\r Proparco (Loan / $90 Million / 2014)       5
#  FMO (Loan / $.. Million / 2012)                                                       4
#  CDC Group (Loan / $26 Million / 2019)                                                 3
#  FMO (Loan / $26 Million / 2019)                                                       3
#                                                                                     ...
#  Agence Francaise de Developpement (AFD) (Loan / $.. Million / 2020)                   1
#  OPIC (Loan / $42 Million / 2014)                                                      1
#  DEG (Loan / $24 Million / 2019)                                                       1
#  CDB (Loan / $263 Million / 2019)                                                      1
#  JICA (Loan / $180 Million / 2012)                                                     1
# Name: BiLateralSupport, Length: 342, dtype: int64
#
# 数据库： Primary sector
# 分类文本数据，无值
# Energy                                                                  6269
# Transport                                                               2600
# <a href="snapshots/sector/water-and-sewerage">Water and sewerage</a>    1285
# Name: Primary sector, dtype: int64
#
# 数据库： UnsolicitedProposal
# 分类文本数据，无值
# Yes    6284
# No     3870
# Name: UnsolicitedProposal, dtype: int64
#
# 数据库： PublicDisclosure
# 分类文本数据，无值
# No     10009
# Yes      145
# Name: PublicDisclosure, dtype: int64
#
# 数据库： Subtype of PPI
# 分类文本数据，无值
# Build, operate, and transfer                  2795
# Build, own, and operate                       2362
# Build, rehabilitate, operate, and transfer    2096
# Rehabilitate, operate, and transfer            850
# Partial                                        811
#                                               ...
# Not Available                                  127
# Rehabilitate, lease or rent, and transfer       89
# Rental                                          80
# Build, lease, and transfer                      29
# Other                                           22
# Name: Subtype of PPI, Length: 14, dtype: int64
#
# 数据库： GovtGrantingContract
# 分类文本数据，无值
# National            4915
# Not Available       2342
# Local/Municipal     1679
# State/Provincial    1202
# Not Applicable        16
# Name: GovtGrantingContract, dtype: int64
#
# 数据库： PercentPrivate
# mean: 90.06112444356904
# max: 100.0
# min: 1.0
#
# 数据库： Subsector
# 分类文本数据，无值
# Electricity                     5503
# Roads                           1408
# Treatment plant                  759
# Natural Gas                      742
# Ports                            657
#                                 ...
# Electricity, Natural Gas           3
# Ports, Railways                    1
# Railways, Roads                    1
# Electricity, Roads                 1
# Electricity, Treatment plant       1
# Name: Subsector, Length: 16, dtype: int64
#
# 数据库： Segment
# 分类文本数据，无值
# Electricity generation                                                                 4060
# Highway                                                                                1231
# Terminal                                                                                672
# Electricity distribution                                                                667
# Natural gas distribution                                                                584
#                                                                                        ...
# Other, Water utility without sewerage                                                     1
# Electricity distribution, generation, and transmission, Water utility with sewerage       1
# Sewerage collection, Sewerage treatment plant                                             1
# Electricity generation, Potable water treatment plant                                     1
# Fixed assets and passenger, Highway                                                       1
# Name: Segment, Length: 59, dtype: int64
#
# 数据库： Main Revenue Source
# 分类文本数据，无值
# Not Applicable                                                                                                                 3777
# Purchase agreements or transmission fees with public entity(ies)                                                               2230
# User fees                                                                                                                      2210
# PPA/WPA payments                                                                                                                720
# Fixed annuity/availability payment(s) from the government                                                                       349
#                                                                                                                                ...
# User fees, \n\rOther                                                                                                              7
# PPA/WPA payments, \n\rOther                                                                                                       5
# Fixed annuity/availability payment(s) from the government, \n\rVariable annuity/availability payment(s) from the government       2
# Fixed annuity/availability payment(s) from the government, \n\rUser fees                                                          2
# Other Toll                                                                                                                        1
# Name: Main Revenue Source, Length: 15, dtype: int64
#
# 数据库： VoiceandAccountability
# mean: -0.26138253798307964
# max: 1.311339259147644
# min: -2.2332706451416016
#
# 数据库： Political StabilityNoViolence
# mean: -0.4816348046480203
# max: 1.1854937076568604
# min: -2.860755443572998
#
# 数据库： GovernmentEffectiveness
# mean: -0.11261011660907429
# max: 1.2542539834976196
# min: -2.1959662437438965
#
# 数据库： RegulatoryQuality
# mean: -0.12645534541980444
# max: 1.196946620941162
# min: -2.2246904373168945
#
# 数据库： RuleofLaw
# mean: -0.2948077377536683
# max: 1.0171523094177246
# min: -2.4182040691375732
#
# 数据库： ControlofCorruption
# mean: -0.3361682156937621
# max: 1.3934845924377441
# min: -1.7698016166687012
#
# 数据库： Access to electricity (% of population)
# mean: 77.96721331411473
# max: 100.0
# min: 0.0
#
# 数据库： Domestic credit to private sector (% of GDP)
# mean: 50.910060080564406
# max: 182.8680594
# min: 0.0
#
# 数据库： Exports of goods and services (% of GDP)
# mean: 23.10994364399419
# max: 121.3113937
# min: 0.0
#
# 数据库： GDP deflator (base year varies by country)
# mean: 88.9382750013508
# max: 9394.987414
# min: 0.0
#
# 数据库： GDP per capita (constant 2015 US$)
# mean: 4888.00378669156
# max: 18948.3865
# min: 0.0
#
# 数据库： Imports of goods and services (% of GDP)
# mean: 24.676138567032204
# max: 118.7639329
# min: 0.0
#
# 数据库： Life expectancy at birth, total (years)
# mean: 66.57815099684952
# max: 79.505
# min: 0.0
#
# 数据库： Official exchange rate (LCU per US$, period average)
# mean: 648.3368462400844
# max: 33226.29815
# min: 0.0
#
# 数据库： Tax revenue (% of GDP)
# mean: 7.369292429956865
# max: 31.69463293
# min: 0.0
